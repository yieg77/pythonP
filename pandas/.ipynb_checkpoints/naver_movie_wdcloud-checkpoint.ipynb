# %%
import urllib
from bs4 import BeautifulSoup
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from soynlp.noun import NewsNounExtractor
from PIL import Image
import numpy as np
# %matplotlib inline

# %%
list_records=[]
for i in range(1,31):
    params=urllib.parse.urlencode({'page':i})
    url="https://movie.naver.com/movie/point/af/list.nhn?&%s" %params

    response=urllib.request.urlopen(url)
    bs = BeautifulSoup(response, 'html.parser')
    table=bs.find('table', class_='list_netizen')

    for i, r in enumerate(table.find_all('tr')):
        #print('i: ', i)
        #print('r: ', r)
        for j,c in enumerate(r.find_all('td')):
            #print('j: ', j)
            #print('c: ', c)
            if j==0:
                record={'번호':int(c.text.strip())}
            elif j==1:
                record.update({'영화':str(c.find('a').text.strip())})
                record.update({'140자 평':str(c.text.strip().replace('\n','').replace('\t',''))})
                record['140자 평']=record['140자 평'][len(record['영화']):-2]
            elif j==2:
                record.update({'글쓴이':c.find('a', class_='author').text.strip()})
                record.update({'날짜':str(c.text).split('****')[1]})
            
        try:
            list_records.append(record)
        except:
            pass


#print(list_records)

# %%
data = pd.DataFrame(list_records)
data.head()
#print(data['140자 평'])
# Out:
#                                               140자 평       글쓴이        날짜  \
# 0            아침에 보지마세요.. 하루종일 조커에 몰입해서 기분이 우울해짐..ㅠㅠ   ghaj****  19.10.04
# 1  영화전개가 음주상태로만 진행되어서별점 2점 깎음김래원 공효진 여성감독이 조합만으로 ...  lord****  19.10.04
# 2  1편에 이어 스토리가 더 쌔졌다. 보면서 혼자 생각하는 것들이 영화속에서 펼쳐지는 ...  yong****  19.10.04
# 3                                      하하하하 이게 인생이야   admi****  19.10.04
# 4                          사회의 독에 던져진 한 인간의 광기와 몸부림   sexy****  19.10.04
#
#          번호         영화
# 0  16234861         조커
# 1  16234860  가장 보통의 연애
# 2  16234859      데드풀 2
# 3  16234858         조커
# 4  16234857         조커

# %%
stopwords_kr = []

def displayWordCloud(data=None, backgroundcolor='white', width=800, height=600):
    #이미지 형태대로 wordcloud 출력
    img = Image.open('apple.png')
    img_array=np.array(img)

    #soynlp로 명사만 빼내기
    noun_extractor = NewsNounExtractor()
    nouns=noun_extractor.train_extract(data['140자 평'])
    #print(type(nouns))

    wordcloud = WordCloud(
        font_path = '/Library/Fonts/HMKMAMI.TTF',
        #font_path = 'C:/Windows/Fonts/HMKMAMI.TTF',
        stopwords = stopwords_kr,
        background_color=backgroundcolor,
        mask=img_array,
        width=width,
        height=height).generate(' '.join(nouns))

    print(wordcloud.words_)
    plt.figure(figsize=(15,10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
   
    wordcloud.to_file('result.png')

displayWordCloud(data)
# Out:
# used default noun predictor; Sejong corpus based logistic predictor
# C:/ProgramData/Anaconda3/lib/site-packages/soynlp
# local variable 'f' referenced before assignment
# local variable 'f' referenced before assignment
# scan vocabulary ...
# done (Lset, Rset, Eojeol) = (6175, 3739, 2430)
# predicting noun score was done
# before postprocessing 466
# _noun_scores_ 125
# checking hardrules ... doneNsubJ (떡볶+(이)), NVsubE (사기(당)+했다) ... done
# after postprocessing 75
# extracted 0 compounds from eojeols{'조커': 1.0, '기분': 1.0, '영화': 1.0, '스토리': 1.0, '생각': 1.0, '사회': 1.0, '인간': 1.0, '광기': 1.0, '호아킨': 1.0, '피닉스': 1.0, '다크나이트': 1.0, '처음': 1.0, '알게': 1.0, '연기': 1.0, '연출': 1.0, '너무': 1.0, '배우': 1.0, '배우들': 1.0, '현실': 1.0, '연애': 1.0, '제목': 1.0, '포스터': 1.0, '감동': 1.0, '눈물': 1.0, '마지막': 1.0, '작품': 1.0, '감독': 1.0, '캐릭터': 1.0, '내용': 1.0, '공감': 1.0, '배트맨': 1.0, '탄생': 1.0, '히어로물': 1.0, '남녀': 1.0, '현실적': 1.0, '가족': 1.0, '지금': 1.0, '연기력': 1.0, '연출력': 1.0, '서예지': 1.0, '최고': 1.0, '재미': 1.0, '분노': 1.0, '모습': 1.0, '과정': 1.0, '작가': 1.0, '여자': 1.0, '사랑': 1.0, '긴장': 1.0, '어디': 1.0, '신경': 1.0, '영상미': 1.0, '개인적': 1.0, '히스레저': 1.0, '한순간': 1.0, '결말': 1.0, '분위기': 1.0, '시간': 1.0, '택시드라이버': 1.0, '한국': 1.0, '표정': 1.0, '기대': 1.0, '조진웅': 1.0, '대사': 1.0, '인물': 1.0, '누구': 1.0, '여자친구': 1.0, '한편': 1.0, '광대': 1.0, 'OST': 1.0, '반전': 1.0, '시원': 1.0, '조커연기': 1.0, '실화': 1.0, '액션': 1.0}
